# %% [markdown]
# ## TP03 : Transformée de Fourier

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
cameraman = cv.imread('cameraman.jpg',0)
trui = cv.imread('trui.png',0)

# %% [markdown]
# #### 1. Trouver la TF de l’image cameraman . Afficher l’image module et celle de l’argument.

# %%
# Transformation de Fourier et conversion en magnitude et phase
f1 = np.fft.fft2(cameraman)
fshift1 = np.fft.fftshift(f1)
magnitude_spectrum1 = 20*np.log(np.abs(fshift1))
phase_spectrum1 = np.angle(fshift1)

# Set the size of the figure
plt.figure(figsize=(7, 3))

# Display the magnitude and phase of the first image
plt.subplot(121)
plt.imshow(magnitude_spectrum1, cmap='gray')
plt.title('Magnitude Spectrum of cameraman')
plt.xticks([]), plt.yticks([])

plt.subplot(122)
plt.imshow(phase_spectrum1, cmap='gray')
plt.title('Phase Spectrum of cameraman')
plt.xticks([]), plt.yticks([])

# Adjust the layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2. Trouver la TF de l’image trui . Afficher l’image module de et celle de l’argument.

# %%
f2 = np.fft.fft2(trui)
fshift2 = np.fft.fftshift(f2)
magnitude_spectrum2 = 20*np.log(np.abs(fshift2))
phase_spectrum2 = np.angle(fshift2)

# Set the size of the figure
plt.figure(figsize=(7, 3))

# Display the magnitude and phase of the first image
plt.subplot(121)
plt.imshow(magnitude_spectrum2, cmap='gray')
plt.title('Magnitude Spectrum of trui')
plt.xticks([]), plt.yticks([])

plt.subplot(122)
plt.imshow(phase_spectrum2, cmap='gray')
plt.title('Phase Spectrum of trui')
plt.xticks([]), plt.yticks([])

# Adjust the layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 3. Construire une 3ème image dont le module de sa TF est égal à celui de cameraman et son argument est celui de l'image trui. Conclusion.

# %%
# Reconstruction d'une nouvelle image avec la magnitude de cameraman et la phase de trui
magnitude_new = np.abs(fshift1)
phase_new = np.angle(fshift2)
new_spectrum = magnitude_new * np.exp(1j * phase_new)
f_new = np.fft.ifftshift(new_spectrum)
new_img = np.fft.ifft2(f_new)
new_img = np.abs(new_img)

# Affichage de la nouvelle image
plt.imshow(new_img, cmap='gray')
plt.title('New Image with cameraman magnitude and trui phase'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# Reconstruction d'une nouvelle image avec la magnitude de cameraman et la phase de trui
magnitude_new = np.abs(fshift2)
phase_new = np.angle(fshift1)
new_spectrum = magnitude_new * np.exp(1j * phase_new)
f_new = np.fft.ifftshift(new_spectrum)
new_img = np.fft.ifft2(f_new)
new_img = np.abs(new_img)

# Affichage de la nouvelle image
plt.imshow(new_img, cmap='gray')
plt.title('New Image with trui magnitude and cameraman phase'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# #### 4. Générer la TF d’un filtre passe-bas de même taille que l'image cameraman. Appliquer ce filtre à l’image dans le domaine fréquentiel. Afficher le résultat. Faites varier la fréquence de coupure $(U_0,V_0)$. Conclusions.

# %%
# Filtre passe-bas
rows, cols = cameraman.shape
crow, ccol = rows//2, cols//2
d = 30 # Fréquence de coupure
mask = np.zeros((rows, cols), np.uint8)
mask[crow-d:crow+d, ccol-d:ccol+d] = 1
fshift1 = fshift1 * mask
f_ishift = np.fft.ifftshift(fshift1)
img_back = np.fft.ifft2(f_ishift)
img_back = np.abs(img_back)

# Affichage de l'image filtrée
plt.subplot(121),plt.imshow(cameraman, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img_back, cmap = 'gray')
plt.title('Low Pass Filtered Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# #### 5. Refaire le même travail demandé avec un filtre passe-haut.

# %%
# Filtre passe-haut
d = 30 # Fréquence de coupure
mask = np.ones((rows, cols), np.uint8)
mask[crow-d:crow+d, ccol-d:ccol+d] = 0
fshift1 = fshift1 * mask
f_ishift = np.fft.ifftshift(fshift1)
img_back = np.fft.ifft2(f_ishift)
img_back = np.abs(img_back)

# Affichage de l'image filtrée
plt.subplot(121),plt.imshow(cameraman,cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img_back, cmap = 'gray')
plt.title('High Pass Filtered Image'), plt.xticks([]), plt.yticks([])
plt.show()
